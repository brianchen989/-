# %% [markdown]
# <a href="https://colab.research.google.com/github/brianchen989/-/blob/main/YOLOv9_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow==9.5.0

# %%
# 連接至雲端硬碟
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 將yolov9資料夾下載至Colab
# !git clone https://github.com/WongKinYiu/yolov9.git  # 原作者網址
# !git clone https://github.com/caijiayou/yolov9_v1.git
# Out:
# Cloning into 'yolov9_v1'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 135 (delta 45), reused 135 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 2.09 MiB | 27.42 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
import os
# 更改資料夾名稱
os.rename("yolov9_v1", "yolov9")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-939639562.py in <cell line: 0>()
#       1 import os
#       2 # 更改資料夾名稱
# ----> 3 os.rename("yolov9_v1", "yolov9")
#
# OSError: [Errno 39] Directory not empty: 'yolov9_v1' -> 'yolov9'

# %%
# 進入yolov9資料夾並安裝相關套件
# %cd yolov9
# !pip install -r requirements.txt
# %cd
# Out:
# /content/yolov9/yolov9
# ...
# /root

# %%
# 複製dataset檔案至colab
# !rm -rf /content/data
# !mkdir /content/data
# !cp /content/drive/MyDrive/dataset.zip /content/data/dataset.zip

# %%
# 解壓縮檔案
# !unzip /content/data/dataset.zip -d /content/data
# !rm -rf /content/data/dataset.zip
# Out:
# Archive:  /content/data/dataset.zip
#    creating: /content/data/DATASET/
#    creating: /content/data/DATASET/images/
#    creating: /content/data/DATASET/images/test/
#   inflating: /content/data/DATASET/images/test/badminton_1.png
#   inflating: /content/data/DATASET/images/test/badminton_170.png
#   inflating: /content/data/DATASET/images/test/badminton_171.png
#   inflating: /content/data/DATASET/images/test/badminton_172.png
#   inflating: /content/data/DATASET/images/test/badminton_173.png
#   inflating: /content/data/DATASET/images/test/badminton_174.png
#   inflating: /content/data/DATASET/images/test/badminton_175.png
#   inflating: /content/data/DATASET/images/test/badminton_176.png
#   inflating: /content/data/DATASET/images/test/badminton_177.png
#   inflating: /content/data/DATASET/images/test/badminton_2.png
#   inflating: /content/data/DATASET/images/test/badminton_3.png
#   inflating: /content/data/DATASET/images/test/badminton_4.png
# ...

# %%
import shutil

# 要移動的目錄路徑
source_dir = '/content/data/DATASET'
# 目標位置的目錄路徑
target_dir = '/content/yolov9/data'

shutil.move(source_dir, target_dir)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-2883638210.py in <cell line: 0>()
#       6 target_dir = '/content/yolov9/data'
#       7
# ----> 8 shutil.move(source_dir, target_dir)
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     843
#     844         if os.path.exists(real_dst):
# --> 845             raise Error("Destination path '%s' already exists" % real_dst)
#     846     try:
#     847         os.rename(src, real_dst)
#
# Error: Destination path '/content/yolov9/data/DATASET' already exists

# %%
# 下載預訓練權重
# !mkdir /content/yolov9/weight
# !wget -O /content/yolov9/weight/yolov9-c.pt https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# Out:
# mkdir: cannot create directory ‘/content/yolov9/weight’: File exists
# --2025-12-02 04:31:05--  https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# train yolov9 models
# %cd /content/yolov9

# !python train_dual.py \
--batch 4 --epochs 20 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/yolov9/data/datasets.yaml \
--weights /content/yolov9/weight/yolov9-c.pt \
--cfg models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2025-12-02 04:35:23.547861: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764650123.567054    8586 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764650123.572829    8586 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764650123.587527    8586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# 測試
# %cd /content/yolov9

# !python detect_dual.py --weights /content/yolov9/runs/train/exp5/weights/best.pt\
--conf 0.75\
--source /content/data/DATASET/images/test/badminton_1.png\
--device 0
# Out:
# /content/yolov9
# detect_dual: weights=['/content/yolov9/runs/train/exp5/weights/best.pt'], source=/content/data/DATASET/images/test/badminton_1.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.75, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 f8fcab5 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50698278 parameters, 0 gradients, 236.6 GFLOPs
# image 1/1 /content/data/DATASET/images/test/badminton_1.png: 384x640 1 player, 81.4ms
# Speed: 0.4ms pre-process, 81.4ms inference, 224.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4
